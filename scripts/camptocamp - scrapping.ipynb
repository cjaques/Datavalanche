# %% [markdown]
#     pip install beautifulsoup4

# %%
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
url = [
    'https://www.camptocamp.org/outings/1056650/fr/sommet-des-diablerets-du-col-du-sanetsch',
    'https://www.camptocamp.org/outings/533744/fr/dent-d-herens-face-w',
    'https://www.camptocamp.org/outings/1007804/fr/fletschhorn-de-la-weissmieshutte',
    'https://www.camptocamp.org/outings#qa=draft%252Cgreat&bbox=-441419%252C4547003%252C1241418%252C6652996&act=skitouring&offset=510'
]

# %%
r = requests.get(url[-1])

# %%
html = BeautifulSoup(r.content, 'html.parser')

# %%
print html.prettify()
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/Article" ng-app="app" ng-controller="MainController as mainCtrl">
#  <head>
#   <title ng-bind="mainCtrl.page_title('Outings')">
#    Outings - Camptocamp.org
#   </title>
#   <meta charset="utf-8">
#    <meta content="initial-scale=1.0, user-scalable=no, width=device-width" name="viewport">
#     <meta content="yes" name="apple-mobile-web-app-capable">
#      <meta content="#F7931D" name="theme-color">
#       <meta content="yes" name="mobile-web-app-capable">
#        <meta content="Camptocamp.org" name="apple-mobile-web-app-title">
#         <meta content="Camptocamp.org" name="application-name">
#          <meta content="yes" name="apple-mobile-web-app-capable">
#           <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style">
#            <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180">
# ...

# %%
text = html.get_text()

# %%
text
# Out:
# u'\n\n\nOutings - Camptocamp.org\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      [ng\\:cloak], [ng-cloak], [data-ng-cloak], [x-ng-cloak], .ng-cloak, .x-ng-cloak {\n        display: none !important;\n      };\n    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTopoguide\n\n\n\n\n\nOutings\n\n\n\n\n\nForum\n\n\n\n\n\nAccident database\n\n\n\n\n\nArticles\n\n\n\n\n\n\n\n\ncontact\n\u2022 \nEULA\n\u2022 \nlicenses\n\nAssociation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nOutings\n{{resCounter}}\n\n\n\n\n\n\n\n\ntitle\n\n\n\nactivities\n\n\n ({{filtersCtrl.filters.act.length}})\n\n\n\n\n\n\n\n{{mainCtrl.translate(val) | capitalize}}\n\n\n\n\n\ncondition_rating\n\n\n\n\n\n\ntitle\n\n\n\nactivities\n\n\n ({{filtersCtrl.filters.act.length}})\n\n\n\n\n\n\n\n{{mainCtrl.translate(val) | capitalize}}\n\n\n\n\n\ncondition_rating\n\n\n\n\ndate_start\n\n\n\n\n\n\n\n\ndate_end\n\n\n\n\n\n\n\n\nelevation_max\n\n\n\nelevation_access\n\n\n\nheight_diff_up\n\n\n\nheight_diff_difficulties\n\n\n\nfrequentation\n\n\n\n\nglobal_rating
# ...
