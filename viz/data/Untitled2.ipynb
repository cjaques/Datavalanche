# %%
import numpy as np
import os
import gpxpy
import gpxpy.gpx

# %%
files = os.listdir('GPS/')

files = ['GPS/' + f for f in files if f[-3:] == 'gpx']

# %%
files
# Out:
# ['GPS/217559.gpx',
#  'GPS/509654.gpx',
#  'GPS/990570.gpx',
#  'GPS/340252.gpx',
#  'GPS/760657.gpx',
#  'GPS/830240.gpx',
#  'GPS/751041.gpx',
#  'GPS/594065.gpx',
#  'GPS/505072.gpx',
#  'GPS/894060.gpx',
#  'GPS/853608.gpx',
#  'GPS/887306.gpx',
#  'GPS/977038.gpx',
#  'GPS/478958.gpx',
#  'GPS/581273.gpx',
#  'GPS/391232.gpx',
#  'GPS/888725.gpx',
#  'GPS/406165.gpx',
#  'GPS/259402.gpx',
#  'GPS/754346.gpx',
#  'GPS/487484.gpx',
#  'GPS/416906.gpx',
#  'GPS/418367.gpx',
#  'GPS/512208.gpx',
#  'GPS/213522.gpx',
#  'GPS/130343.gpx',
#  'GPS/495844.gpx',
#  'GPS/879959.gpx',
#  'GPS/889254.gpx',
#  'GPS/196883.gpx',
#  'GPS/872396.gpx',
#  'GPS/121089.gpx',
#  'GPS/780667.gpx',
#  'GPS/870843.gpx',
#  'GPS/851829.gpx',
#  'GPS/744980.gpx',
#  'GPS/959854.gpx',
#  'GPS/109321.gpx',
#  'GPS/702138.gpx',
#  'GPS/869652.gpx',
#  'GPS/245561.gpx',
#  'GPS/494088.gpx',
#  'GPS/398150.gpx',
#  'GPS/850373.gpx',
#  'GPS/503825.gpx',
#  'GPS/1034416.gpx',
#  'GPS/977352.gpx',
#  'GPS/328425.gpx',
#  'GPS/488512.gpx',
#  'GPS/327105.gpx',
#  'GPS/492613.gpx',
#  'GPS/954677.gpx',
#  'GPS/874358.gpx',
#  'GPS/489148.gpx',
#  'GPS/430123.gpx',
#  'GPS/600736.gpx',
#  'GPS/732715.gpx',
#  'GPS/331353.gpx',
#  'GPS/425398.gpx',
#  'GPS/832252.gpx',
#  'GPS/411764.gpx',
#  'GPS/880956.gpx',
#  'GPS/978370.gpx',
#  'GPS/496203.gpx',
#  'GPS/266613.gpx',
#  'GPS/393873.gpx',
#  'GPS/501955.gpx',
#  'GPS/988744.gpx',
#  'GPS/736572.gpx',
#  'GPS/504748.gpx',
#  'GPS/998871.gpx',
#  'GPS/986777.gpx',
#  'GPS/410591.gpx',
#  'GPS/976989.gpx',
#  'GPS/98842.gpx',
#  'GPS/195935.gpx',
#  'GPS/275983.gpx',
#  'GPS/411399.gpx',
#  'GPS/854081.gpx',
#  'GPS/351549.gpx',
#  'GPS/403524.gpx',
#  'GPS/597449.gpx',
#  'GPS/878513.gpx',
#  'GPS/878505.gpx',
#  'GPS/859938.gpx',
#  'GPS/163128.gpx',
#  'GPS/473897.gpx',
#  'GPS/166216.gpx',
#  'GPS/507902.gpx',
#  'GPS/111325.gpx',
#  'GPS/732146.gpx',
#  'GPS/991295.gpx',
#  'GPS/508504.gpx',
#  'GPS/280758.gpx',
#  'GPS/398318.gpx',
#  'GPS/865046.gpx',
#  'GPS/198523.gpx',
#  'GPS/206684.gpx',
#  'GPS/952022.gpx',
#  'GPS/624904.gpx',
#  'GPS/589562.gpx',
#  'GPS/408846.gpx',
#  'GPS/967298.gpx',
#  'GPS/274221.gpx',
#  'GPS/336933.gpx',
#  'GPS/996796.gpx',
#  'GPS/851720.gpx',
#  'GPS/848493.gpx',
#  'GPS/635925.gpx',
#  'GPS/497973.gpx',
#  'GPS/832790.gpx',
#  'GPS/271138.gpx',
#  'GPS/194481.gpx',
#  'GPS/486578.gpx',
#  'GPS/612112.gpx',
#  'GPS/248869.gpx',
#  'GPS/421322.gpx',
#  'GPS/876886.gpx',
#  'GPS/850594.gpx',
#  'GPS/262106.gpx',
#  'GPS/532986.gpx',
#  'GPS/978305.gpx',
#  'GPS/717329.gpx',
#  'GPS/250099.gpx',
#  'GPS/270299.gpx',
#  'GPS/495967.gpx',
#  'GPS/872243.gpx',
#  'GPS/160235.gpx',
#  'GPS/391348.gpx',
#  'GPS/425552.gpx',
#  'GPS/951080.gpx',
#  'GPS/94806.gpx',
#  'GPS/273640.gpx',
#  'GPS/508808.gpx',
#  'GPS/477003.gpx',
#  'GPS/524533.gpx',
#  'GPS/751244.gpx',
#  'GPS/611447.gpx',
#  'GPS/997240.gpx',
#  'GPS/397475.gpx',
#  'GPS/999288.gpx',
#  'GPS/172338.gpx',
#  'GPS/1005768.gpx',
#  'GPS/731812.gpx',
#  'GPS/853317.gpx',
#  'GPS/883137.gpx',
#  'GPS/490679.gpx',
#  'GPS/858530.gpx',
#  'GPS/761893.gpx',
#  'GPS/961246.gpx',
#  'GPS/612943.gpx',
#  'GPS/346484.gpx',
#  'GPS/487754.gpx',
#  'GPS/256233.gpx',
#  'GPS/196205.gpx',
#  'GPS/320707.gpx',
#  'GPS/984339.gpx',
#  'GPS/270054.gpx',
#  'GPS/999901.gpx',
#  'GPS/714522.gpx',
#  'GPS/483412.gpx',
#  'GPS/842832.gpx',
#  'GPS/585245.gpx',
#  'GPS/520300.gpx',
#  'GPS/391683.gpx',
#  'GPS/716541.gpx',
#  'GPS/721546.gpx',
#  'GPS/480100.gpx',
#  'GPS/253172.gpx',
#  'GPS/476553.gpx',
#  'GPS/501148.gpx',
#  'GPS/974523.gpx',
#  'GPS/608987.gpx',
#  'GPS/889145.gpx',
#  'GPS/1008976.gpx',
#  'GPS/322765.gpx',
#  'GPS/735318.gpx',
#  'GPS/212407.gpx',
#  'GPS/265987.gpx',
#  'GPS/425384.gpx',
#  'GPS/958411.gpx',
#  'GPS/611338.gpx',
#  'GPS/498737.gpx',
#  'GPS/501329.gpx',
#  'GPS/484986.gpx',
#  'GPS/398145.gpx',
#  'GPS/735308.gpx',
#  'GPS/982550.gpx',
#  'GPS/611274.gpx',
#  'GPS/717624.gpx',
#  'GPS/721566.gpx',
#  'GPS/831341.gpx',
#  'GPS/745540.gpx',
#  'GPS/585682.gpx',
#  'GPS/481004.gpx',
#  'GPS/203313.gpx',
#  'GPS/856631.gpx',
#  'GPS/989313.gpx',
#  'GPS/839416.gpx',
#  'GPS/748173.gpx',
#  'GPS/610324.gpx',
#  'GPS/721104.gpx',
#  'GPS/881683.gpx',
#  'GPS/425923.gpx',
#  'GPS/166276.gpx',
#  'GPS/961559.gpx',
#  'GPS/861318.gpx',
#  'GPS/510126.gpx',
#  'GPS/442690.gpx',
#  'GPS/842833.gpx',
#  'GPS/270019.gpx',
#  'GPS/861877.gpx',
#  'GPS/491302.gpx',
#  'GPS/865011.gpx',
#  'GPS/592301.gpx',
#  'GPS/595573.gpx',
#  'GPS/958705.gpx',
#  'GPS/267729.gpx',
#  'GPS/870719.gpx',
#  'GPS/410291.gpx',
#  'GPS/735416.gpx',
#  'GPS/983326.gpx',
#  'GPS/341421.gpx',
#  'GPS/257790.gpx',
#  'GPS/278306.gpx',
#  'GPS/1006108.gpx',
#  'GPS/731604.gpx',
#  'GPS/256081.gpx',
#  'GPS/708510.gpx',
#  'GPS/164730.gpx',
#  'GPS/527036.gpx',
#  'GPS/710364.gpx',
#  'GPS/878481.gpx',
#  'GPS/611502.gpx',
#  'GPS/736740.gpx',
#  'GPS/639016.gpx',
#  'GPS/974832.gpx',
#  'GPS/612339.gpx',
#  'GPS/1058406.gpx',
#  'GPS/474822.gpx',
#  'GPS/417157.gpx',
#  'GPS/878138.gpx',
#  'GPS/586438.gpx',
#  'GPS/755993.gpx',
#  'GPS/730112.gpx',
#  'GPS/480101.gpx',
#  'GPS/409961.gpx',
#  'GPS/489564.gpx',
#  'GPS/1058104.gpx',
#  'GPS/998784.gpx',
#  'GPS/768454.gpx',
#  'GPS/616554.gpx',
#  'GPS/886012.gpx',
#  'GPS/977963.gpx',
#  'GPS/1058878.gpx',
#  'GPS/1007772.gpx',
#  'GPS/981851.gpx',
#  'GPS/266886.gpx',
#  'GPS/830106.gpx',
#  'GPS/870608.gpx',
#  'GPS/591401.gpx',
#  'GPS/889719.gpx',
#  'GPS/964303.gpx',
#  'GPS/201723.gpx',
#  'GPS/626000.gpx',
#  'GPS/867403.gpx',
#  'GPS/480640.gpx',
#  'GPS/420392.gpx',
#  'GPS/850636.gpx',
#  'GPS/721133.gpx',
#  'GPS/730440.gpx',
#  'GPS/743718.gpx',
#  'GPS/831410.gpx',
#  'GPS/991435.gpx',
#  'GPS/983092.gpx',
#  'GPS/418546.gpx',
#  'GPS/1003387.gpx',
#  'GPS/873592.gpx',
#  'GPS/473675.gpx',
#  'GPS/519566.gpx',
#  'GPS/873956.gpx',
#  'GPS/509655.gpx',
#  'GPS/703595.gpx',
#  'GPS/873576.gpx',
#  'GPS/831710.gpx',
#  'GPS/534126.gpx',
#  'GPS/338724.gpx',
#  'GPS/849619.gpx',
#  'GPS/702221.gpx',
#  'GPS/321153.gpx',
#  'GPS/836448.gpx',
#  'GPS/519806.gpx',
#  'GPS/424729.gpx',
#  'GPS/426928.gpx',
#  'GPS/272381.gpx',
#  'GPS/163108.gpx',
#  'GPS/433909.gpx',
#  'GPS/845951.gpx',
#  'GPS/201151.gpx',
#  'GPS/598497.gpx',
#  'GPS/965155.gpx',
#  'GPS/747536.gpx',
#  'GPS/506288.gpx',
#  'GPS/420226.gpx',
#  'GPS/634025.gpx',
#  'GPS/253845.gpx',
#  'GPS/845965.gpx',
#  'GPS/852208.gpx',
#  'GPS/215952.gpx',
#  'GPS/829047.gpx',
#  'GPS/1001454.gpx',
#  'GPS/274794.gpx',
#  'GPS/417565.gpx',
#  'GPS/714754.gpx',
#  'GPS/731215.gpx',
#  'GPS/506721.gpx',
#  'GPS/322963.gpx',
#  'GPS/644889.gpx',
#  'GPS/732178.gpx',
#  'GPS/435589.gpx',
#  'GPS/976893.gpx',
#  'GPS/861860.gpx',
#  'GPS/267006.gpx',
#  'GPS/972293.gpx',
#  'GPS/478298.gpx',
#  'GPS/845810.gpx',
#  'GPS/1002971.gpx',
#  'GPS/170459.gpx',
#  'GPS/632557.gpx',
#  'GPS/610896.gpx',
#  'GPS/990654.gpx',
#  'GPS/947864.gpx',
#  'GPS/999264.gpx',
#  'GPS/398187.gpx',
#  'GPS/478231.gpx',
#  'GPS/336080.gpx',
#  'GPS/492164.gpx',
#  'GPS/831709.gpx',
#  'GPS/603843.gpx',
#  'GPS/264560.gpx',
#  'GPS/581935.gpx',
#  'GPS/843623.gpx',
#  'GPS/866143.gpx',
#  'GPS/504370.gpx',
#  'GPS/969897.gpx',
#  'GPS/586441.gpx',
#  'GPS/486621.gpx',
#  'GPS/316693.gpx',
#  'GPS/845588.gpx',
#  'GPS/854528.gpx',
#  'GPS/632813.gpx',
#  'GPS/425478.gpx',
#  'GPS/588510.gpx',
#  'GPS/506854.gpx',
#  'GPS/212828.gpx',
#  'GPS/615263.gpx',
#  'GPS/494629.gpx',
#  'GPS/710324.gpx',
#  'GPS/987486.gpx',
#  'GPS/347662.gpx',
#  'GPS/866137.gpx',
#  'GPS/987059.gpx',
#  'GPS/387871.gpx',
#  'GPS/480960.gpx',
#  'GPS/881343.gpx',
#  'GPS/876922.gpx',
#  'GPS/422098.gpx',
#  'GPS/590590.gpx',
#  'GPS/435681.gpx',
#  'GPS/992760.gpx',
#  'GPS/315917.gpx',
#  'GPS/331740.gpx',
#  'GPS/873103.gpx',
#  'GPS/487885.gpx',
#  'GPS/946184.gpx',
#  'GPS/761250.gpx',
#  'GPS/253881.gpx',
#  'GPS/891330.gpx',
#  'GPS/479493.gpx',
#  'GPS/859443.gpx',
#  'GPS/860358.gpx',
#  'GPS/837694.gpx',
#  'GPS/966300.gpx',
#  'GPS/751269.gpx',
#  'GPS/870010.gpx',
#  'GPS/482376.gpx',
#  'GPS/993278.gpx',
#  'GPS/950648.gpx',
#  'GPS/865777.gpx',
#  'GPS/709479.gpx',
#  'GPS/249607.gpx',
#  'GPS/398420.gpx',
#  'GPS/887576.gpx',
#  'GPS/333875.gpx',
#  'GPS/611696.gpx',
#  'GPS/974037.gpx',
#  'GPS/198271.gpx',
#  'GPS/979072.gpx',
#  'GPS/428372.gpx',
#  'GPS/212471.gpx',
#  'GPS/416966.gpx',
#  'GPS/982522.gpx',
#  'GPS/634626.gpx',
#  'GPS/330068.gpx',
#  'GPS/197335.gpx',
#  'GPS/496811.gpx',
#  'GPS/887307.gpx',
#  'GPS/1017232.gpx',
#  'GPS/583972.gpx',
#  'GPS/585652.gpx',
#  'GPS/406424.gpx',
#  'GPS/498716.gpx',
#  'GPS/624194.gpx',
#  'GPS/997185.gpx',
#  'GPS/995432.gpx',
#  'GPS/856086.gpx',
#  'GPS/397133.gpx',
#  'GPS/225498.gpx',
#  'GPS/431713.gpx',
#  'GPS/725647.gpx',
#  'GPS/981783.gpx',
#  'GPS/496330.gpx',
#  'GPS/413630.gpx',
#  'GPS/599601.gpx',
#  'GPS/735910.gpx',
#  'GPS/853435.gpx',
#  'GPS/586437.gpx',
#  'GPS/842309.gpx',
#  'GPS/758889.gpx',
#  'GPS/723657.gpx',
#  'GPS/856517.gpx',
#  'GPS/351445.gpx',
#  'GPS/628493.gpx',
#  'GPS/995190.gpx',
#  'GPS/483715.gpx',
#  'GPS/625181.gpx',
#  'GPS/609825.gpx',
#  'GPS/146365.gpx',
#  'GPS/975074.gpx',
#  'GPS/214961.gpx',
#  'GPS/211142.gpx',
#  'GPS/264905.gpx',
#  'GPS/503626.gpx',
#  'GPS/387815.gpx',
#  'GPS/504237.gpx',
#  'GPS/205918.gpx',
#  'GPS/853731.gpx',
#  'GPS/636549.gpx',
#  'GPS/336795.gpx',
#  'GPS/876700.gpx',
#  'GPS/112065.gpx',
#  'GPS/589340.gpx',
#  'GPS/987303.gpx',
#  'GPS/991869.gpx',
#  'GPS/519889.gpx',
#  'GPS/954242.gpx',
#  'GPS/739701.gpx',
#  'GPS/841424.gpx',
#  'GPS/203059.gpx',
#  'GPS/870778.gpx',
#  'GPS/130648.gpx',
#  'GPS/857311.gpx',
#  'GPS/843973.gpx',
#  'GPS/873730.gpx',
#  'GPS/397924.gpx',
#  'GPS/257524.gpx',
#  'GPS/267393.gpx',
#  'GPS/958940.gpx',
#  'GPS/968692.gpx',
#  'GPS/487650.gpx',
#  'GPS/512470.gpx',
#  'GPS/949456.gpx',
#  'GPS/861975.gpx',
#  'GPS/329582.gpx',
#  'GPS/946147.gpx',
#  'GPS/611300.gpx',
#  'GPS/579627.gpx',
#  'GPS/979312.gpx',
#  'GPS/745852.gpx',
#  'GPS/474297.gpx',
#  'GPS/870195.gpx',
#  'GPS/591330.gpx',
#  'GPS/167767.gpx',
#  'GPS/883049.gpx',
#  'GPS/862233.gpx',
#  'GPS/1059676.gpx',
#  'GPS/950747.gpx',
#  'GPS/987152.gpx',
#  'GPS/252415.gpx',
#  'GPS/494696.gpx',
#  'GPS/310971.gpx',
#  'GPS/736904.gpx',
#  'GPS/881643.gpx',
#  'GPS/848439.gpx',
#  'GPS/259539.gpx',
#  'GPS/971047.gpx',
#  'GPS/860723.gpx',
#  'GPS/264583.gpx',
#  'GPS/509335.gpx',
#  'GPS/418336.gpx',
#  'GPS/420368.gpx',
#  'GPS/731396.gpx',
#  'GPS/489373.gpx',
#  'GPS/600735.gpx',
#  'GPS/478820.gpx',
#  'GPS/577915.gpx',
#  'GPS/532267.gpx',
#  'GPS/950784.gpx',
#  'GPS/889333.gpx',
#  'GPS/867098.gpx',
#  'GPS/612012.gpx',
#  'GPS/852155.gpx',
#  'GPS/168581.gpx',
#  'GPS/264609.gpx',
#  'GPS/212913.gpx',
#  'GPS/145339.gpx',
#  'GPS/389696.gpx',
#  'GPS/750806.gpx',
#  'GPS/208358.gpx',
#  'GPS/1058416.gpx',
#  'GPS/981156.gpx',
#  'GPS/488252.gpx',
#  'GPS/531014.gpx',
#  'GPS/709745.gpx',
#  'GPS/172609.gpx',
#  'GPS/969754.gpx',
#  'GPS/641228.gpx',
#  'GPS/399494.gpx',
#  'GPS/255582.gpx',
#  'GPS/435502.gpx',
#  'GPS/856665.gpx',
#  'GPS/608044.gpx',
#  'GPS/217621.gpx',
#  'GPS/432697.gpx',
#  'GPS/582495.gpx',
#  'GPS/585078.gpx',
#  'GPS/165766.gpx',
#  'GPS/499751.gpx',
#  'GPS/618579.gpx',
#  'GPS/259341.gpx',
#  'GPS/602328.gpx',
#  'GPS/980086.gpx',
#  'GPS/877025.gpx',
#  'GPS/444146.gpx',
#  'GPS/95253.gpx',
#  'GPS/854424.gpx',
#  'GPS/894863.gpx',
#  'GPS/998774.gpx',
#  'GPS/843229.gpx',
#  'GPS/856488.gpx',
#  'GPS/318666.gpx',
#  'GPS/495991.gpx',
#  'GPS/845638.gpx',
#  'GPS/998478.gpx',
#  'GPS/321727.gpx',
#  'GPS/607381.gpx',
#  'GPS/986441.gpx',
#  'GPS/999169.gpx',
#  'GPS/754859.gpx',
#  'GPS/874553.gpx',
#  'GPS/716029.gpx',
#  'GPS/856416.gpx',
#  'GPS/604881.gpx',
#  'GPS/622108.gpx',
#  'GPS/596237.gpx',
#  'GPS/170089.gpx',
#  'GPS/999370.gpx',
#  'GPS/615806.gpx',
#  'GPS/947276.gpx',
#  'GPS/862692.gpx',
#  'GPS/491010.gpx',
#  'GPS/998022.gpx',
#  'GPS/514998.gpx',
#  'GPS/600201.gpx',
#  'GPS/216096.gpx',
#  'GPS/948173.gpx',
#  'GPS/116842.gpx',
#  'GPS/260076.gpx',
#  'GPS/108032.gpx',
#  'GPS/527049.gpx',
#  'GPS/720244.gpx',
#  'GPS/261910.gpx',
#  'GPS/837691.gpx',
#  'GPS/417985.gpx',
#  'GPS/839191.gpx',
#  'GPS/722759.gpx',
#  'GPS/125583.gpx',
#  'GPS/428388.gpx',
#  'GPS/744173.gpx',
#  'GPS/494428.gpx',
#  'GPS/153859.gpx',
#  'GPS/415722.gpx',
#  'GPS/333061.gpx',
#  'GPS/860001.gpx',
#  'GPS/163095.gpx',
#  'GPS/744002.gpx',
#  'GPS/581962.gpx',
#  'GPS/610712.gpx',
#  'GPS/849515.gpx',
#  'GPS/613481.gpx',
#  'GPS/499140.gpx',
#  'GPS/964192.gpx',
#  'GPS/881000.gpx',
#  'GPS/862179.gpx',
#  'GPS/867484.gpx',
#  'GPS/703180.gpx',
#  'GPS/607132.gpx',
#  'GPS/392999.gpx',
#  'GPS/716848.gpx',
#  'GPS/320329.gpx',
#  'GPS/743157.gpx',
#  'GPS/263107.gpx',
#  'GPS/515318.gpx',
#  'GPS/624885.gpx',
#  'GPS/849906.gpx',
#  'GPS/320321.gpx',
#  'GPS/952439.gpx',
#  'GPS/883527.gpx',
#  'GPS/871808.gpx',
#  'GPS/342044.gpx',
#  'GPS/866496.gpx',
#  'GPS/727240.gpx',
#  'GPS/116812.gpx',
#  'GPS/851799.gpx',
#  'GPS/498823.gpx',
#  'GPS/856859.gpx',
#  'GPS/267096.gpx',
#  'GPS/833600.gpx',
#  'GPS/324886.gpx',
#  'GPS/889259.gpx',
#  'GPS/745934.gpx',
#  'GPS/252799.gpx',
#  'GPS/871814.gpx',
#  'GPS/95049.gpx',
#  'GPS/845821.gpx',
#  'GPS/868972.gpx',
#  'GPS/319694.gpx',
#  'GPS/584162.gpx',
#  'GPS/327600.gpx',
#  'GPS/166565.gpx',
#  'GPS/729274.gpx',
#  'GPS/977951.gpx',
#  'GPS/600991.gpx',
#  'GPS/707431.gpx',
#  'GPS/156938.gpx',
#  'GPS/214008.gpx',
#  'GPS/739300.gpx',
#  'GPS/385835.gpx',
#  'GPS/147442.gpx',
#  'GPS/961828.gpx',
#  'GPS/845665.gpx',
#  'GPS/583490.gpx',
#  'GPS/603925.gpx',
#  'GPS/704170.gpx',
#  'GPS/842423.gpx',
#  'GPS/835822.gpx',
#  'GPS/603518.gpx',
#  'GPS/405781.gpx',
#  'GPS/877142.gpx',
#  'GPS/831280.gpx',
#  'GPS/255952.gpx',
#  'GPS/949131.gpx',
#  'GPS/724293.gpx',
#  'GPS/607126.gpx',
#  'GPS/399732.gpx',
#  'GPS/491813.gpx',
#  'GPS/199636.gpx',
#  'GPS/503590.gpx',
#  'GPS/484014.gpx',
#  'GPS/386766.gpx',
#  'GPS/505543.gpx',
#  'GPS/125885.gpx',
#  'GPS/394313.gpx',
#  'GPS/413587.gpx',
#  'GPS/425695.gpx',
#  'GPS/260987.gpx',
#  'GPS/501452.gpx',
#  'GPS/277652.gpx',
#  'GPS/889262.gpx',
#  'GPS/405717.gpx',
#  'GPS/952300.gpx',
#  'GPS/588661.gpx',
#  'GPS/166690.gpx',
#  'GPS/859653.gpx',
#  'GPS/843825.gpx',
#  'GPS/165574.gpx',
#  'GPS/314111.gpx',
#  'GPS/195228.gpx',
#  'GPS/261028.gpx',
#  'GPS/515218.gpx',
#  'GPS/489059.gpx',
#  'GPS/508119.gpx',
#  'GPS/994388.gpx',
#  'GPS/991347.gpx',
#  'GPS/393290.gpx',
#  'GPS/221635.gpx',
#  'GPS/860582.gpx',
#  'GPS/126394.gpx',
#  'GPS/491360.gpx',
#  'GPS/406039.gpx',
#  'GPS/735940.gpx',
#  'GPS/589771.gpx',
#  'GPS/873230.gpx',
#  'GPS/316126.gpx',
#  'GPS/396563.gpx',
#  'GPS/843662.gpx',
#  'GPS/836897.gpx',
#  'GPS/997354.gpx',
#  'GPS/519621.gpx',
#  'GPS/855930.gpx',
#  'GPS/993870.gpx',
#  'GPS/518847.gpx',
#  'GPS/249090.gpx',
#  'GPS/522176.gpx',
#  'GPS/989906.gpx',
#  'GPS/998833.gpx',
#  'GPS/722337.gpx',
#  'GPS/116256.gpx',
#  'GPS/392005.gpx',
#  'GPS/860051.gpx',
#  'GPS/853010.gpx',
#  'GPS/766127.gpx',
#  'GPS/733201.gpx',
#  'GPS/215850.gpx',
#  'GPS/199793.gpx',
#  'GPS/197880.gpx',
#  'GPS/1009268.gpx',
#  'GPS/493529.gpx',
#  'GPS/495465.gpx',
#  'GPS/166143.gpx',
#  'GPS/420250.gpx',
#  'GPS/526648.gpx',
#  'GPS/978755.gpx',
#  'GPS/850032.gpx',
#  'GPS/600707.gpx',
#  'GPS/132203.gpx',
#  'GPS/955665.gpx',
#  'GPS/166331.gpx',
#  'GPS/890529.gpx',
#  'GPS/201105.gpx',
#  'GPS/727917.gpx',
#  'GPS/395085.gpx',
#  'GPS/330109.gpx',
#  'GPS/412765.gpx',
#  'GPS/880746.gpx',
#  'GPS/210672.gpx',
#  'GPS/244798.gpx',
#  'GPS/853225.gpx',
#  'GPS/269058.gpx',
#  'GPS/339611.gpx',
#  'GPS/320537.gpx',
#  'GPS/753256.gpx',
#  'GPS/855053.gpx',
#  'GPS/420157.gpx',
#  'GPS/416685.gpx',
#  'GPS/773280.gpx',
#  'GPS/511127.gpx',
#  'GPS/143806.gpx',
#  'GPS/748298.gpx',
#  'GPS/323271.gpx',
#  'GPS/975782.gpx',
#  'GPS/1007550.gpx',
#  'GPS/403012.gpx',
#  'GPS/427110.gpx',
#  'GPS/153201.gpx',
#  'GPS/741168.gpx',
#  'GPS/415349.gpx',
#  'GPS/1061489.gpx',
#  'GPS/707673.gpx',
#  'GPS/885881.gpx',
#  'GPS/974949.gpx',
#  'GPS/348372.gpx',
#  'GPS/251752.gpx',
#  'GPS/400775.gpx',
#  'GPS/889225.gpx',
#  'GPS/330847.gpx',
#  'GPS/163200.gpx',
#  'GPS/425092.gpx',
#  'GPS/865401.gpx',
#  'GPS/987069.gpx',
#  'GPS/703903.gpx',
#  'GPS/828778.gpx',
#  'GPS/196206.gpx',
#  'GPS/502220.gpx',
#  'GPS/732593.gpx',
#  'GPS/213782.gpx',
#  'GPS/872760.gpx',
#  'GPS/429578.gpx',
#  'GPS/600544.gpx',
#  'GPS/511293.gpx',
#  'GPS/978771.gpx',
#  'GPS/502653.gpx',
#  'GPS/867424.gpx',
#  'GPS/886249.gpx',
#  'GPS/857163.gpx',
#  'GPS/871106.gpx',
#  'GPS/731292.gpx',
#  'GPS/613398.gpx',
#  'GPS/965334.gpx',
#  'GPS/1005393.gpx',
#  'GPS/165457.gpx',
#  'GPS/717705.gpx',
#  'GPS/484470.gpx',
#  'GPS/996281.gpx',
#  'GPS/1060925.gpx',
#  'GPS/732250.gpx',
#  'GPS/415214.gpx',
#  'GPS/869892.gpx',
#  'GPS/594175.gpx',
#  'GPS/832607.gpx',
#  'GPS/315397.gpx',
#  'GPS/848438.gpx',
#  'GPS/865015.gpx',
#  'GPS/337453.gpx',
#  'GPS/989349.gpx',
#  'GPS/98211.gpx',
#  'GPS/264904.gpx',
#  'GPS/885899.gpx',
#  'GPS/588184.gpx',
#  'GPS/949357.gpx',
#  'GPS/850956.gpx',
#  'GPS/245955.gpx',
#  'GPS/430582.gpx',
#  'GPS/966571.gpx',
#  'GPS/501717.gpx',
#  'GPS/1006664.gpx',
#  'GPS/974137.gpx',
#  'GPS/524055.gpx',
#  'GPS/402777.gpx',
#  'GPS/870465.gpx',
#  'GPS/261562.gpx',
#  'GPS/742360.gpx',
#  'GPS/611504.gpx',
#  'GPS/700050.gpx',
#  'GPS/999922.gpx',
#  'GPS/998287.gpx',
#  'GPS/500047.gpx',
#  'GPS/391184.gpx',
#  'GPS/987167.gpx',
#  'GPS/597365.gpx',
#  'GPS/957440.gpx',
#  'GPS/273150.gpx',
#  'GPS/992960.gpx',
#  'GPS/864742.gpx',
#  'GPS/839103.gpx',
#  'GPS/388359.gpx',
#  'GPS/844832.gpx',
#  'GPS/410436.gpx',
#  'GPS/435798.gpx',
#  'GPS/162669.gpx',
#  'GPS/842875.gpx',
#  'GPS/222885.gpx',
#  'GPS/865862.gpx',
#  'GPS/422633.gpx',
#  'GPS/964637.gpx',
#  'GPS/168500.gpx',
#  'GPS/869334.gpx',
#  'GPS/857389.gpx',
#  'GPS/996212.gpx',
#  'GPS/977127.gpx',
#  'GPS/843507.gpx',
#  'GPS/352035.gpx',
#  'GPS/247034.gpx',
#  'GPS/976752.gpx',
#  'GPS/741730.gpx',
#  'GPS/973533.gpx',
#  'GPS/390525.gpx',
#  'GPS/249284.gpx',
#  'GPS/595099.gpx',
#  'GPS/485726.gpx',
#  'GPS/579180.gpx',
#  'GPS/499106.gpx',
#  'GPS/406884.gpx',
#  'GPS/875841.gpx',
#  'GPS/857184.gpx',
#  'GPS/427085.gpx',
#  'GPS/710365.gpx',
#  'GPS/336500.gpx',
#  'GPS/478633.gpx',
#  'GPS/334137.gpx',
#  'GPS/626026.gpx',
#  'GPS/630194.gpx',
#  'GPS/490837.gpx',
#  'GPS/988864.gpx',
#  'GPS/410359.gpx',
#  'GPS/730033.gpx',
#  'GPS/110566.gpx',
#  'GPS/1005749.gpx',
#  'GPS/413990.gpx',
#  'GPS/837440.gpx',
#  'GPS/274638.gpx',
#  'GPS/982269.gpx',
#  'GPS/325560.gpx',
#  'GPS/981767.gpx',
#  'GPS/736742.gpx',
#  'GPS/215677.gpx',
#  'GPS/490149.gpx',
#  'GPS/428647.gpx',
#  'GPS/496145.gpx',
#  'GPS/484987.gpx',
#  'GPS/845857.gpx',
#  'GPS/999465.gpx',
#  'GPS/959768.gpx',
#  'GPS/121816.gpx',
#  'GPS/504542.gpx',
#  'GPS/976919.gpx',
#  'GPS/427379.gpx',
#  'GPS/495091.gpx',
#  'GPS/504383.gpx',
#  'GPS/490793.gpx',
#  'GPS/268502.gpx',
#  'GPS/422907.gpx',
#  'GPS/841632.gpx',
#  'GPS/740200.gpx',
#  'GPS/588061.gpx',
#  'GPS/216079.gpx',
#  'GPS/197830.gpx',
#  'GPS/844573.gpx',
#  'GPS/968013.gpx',
#  'GPS/195210.gpx',
#  'GPS/846752.gpx',
#  'GPS/956430.gpx',
#  'GPS/868639.gpx',
#  'GPS/738441.gpx',
#  'GPS/954044.gpx',
#  'GPS/959644.gpx',
#  'GPS/257887.gpx',
#  'GPS/974105.gpx',
#  'GPS/876223.gpx',
#  'GPS/852084.gpx',
#  'GPS/225181.gpx',
#  'GPS/842934.gpx',
#  'GPS/633663.gpx',
#  'GPS/1006669.gpx',
#  'GPS/1059416.gpx',
#  'GPS/625960.gpx',
#  'GPS/629367.gpx',
#  'GPS/475524.gpx',
#  'GPS/629433.gpx',
#  'GPS/607858.gpx',
#  'GPS/954109.gpx',
#  'GPS/878807.gpx',
#  'GPS/476943.gpx',
#  'GPS/265838.gpx',
#  'GPS/313711.gpx',
#  'GPS/750725.gpx',
#  'GPS/254849.gpx',
#  'GPS/860974.gpx',
#  'GPS/749197.gpx',
#  'GPS/488879.gpx',
#  'GPS/256420.gpx',
#  'GPS/621690.gpx',
#  'GPS/981908.gpx',
#  'GPS/483718.gpx',
#  'GPS/329152.gpx',
#  'GPS/891270.gpx',
#  'GPS/956617.gpx',
#  'GPS/880162.gpx',
#  'GPS/985265.gpx',
#  'GPS/390608.gpx',
#  'GPS/519803.gpx',
#  'GPS/318136.gpx',
#  'GPS/257126.gpx',
#  'GPS/876072.gpx',
#  'GPS/740149.gpx',
#  'GPS/521885.gpx',
#  'GPS/868635.gpx',
#  'GPS/484957.gpx',
#  'GPS/850111.gpx',
#  'GPS/392463.gpx',
#  'GPS/602012.gpx',
#  'GPS/726527.gpx',
#  'GPS/201315.gpx',
#  'GPS/276320.gpx',
#  'GPS/881819.gpx',
#  'GPS/737797.gpx',
#  'GPS/251890.gpx',
#  'GPS/850305.gpx',
#  'GPS/970682.gpx',
#  'GPS/1008298.gpx',
#  'GPS/1005447.gpx',
#  'GPS/408451.gpx',
#  'GPS/405335.gpx',
#  'GPS/864783.gpx',
#  'GPS/866925.gpx',
#  'GPS/715342.gpx',
#  'GPS/957158.gpx',
#  'GPS/216496.gpx',
#  'GPS/704517.gpx',
#  'GPS/861820.gpx',
#  'GPS/972364.gpx',
#  'GPS/396368.gpx',
#  'GPS/987289.gpx',
#  'GPS/870185.gpx',
#  'GPS/742546.gpx',
#  'GPS/625601.gpx',
#  'GPS/982172.gpx',
#  'GPS/480942.gpx',
#  'GPS/970652.gpx',
#  'GPS/394556.gpx',
#  ...]

# %%
gpxs = [gpxpy.parse(open(f, 'r')) for f  in files]

# %%
points = []

for gpx in gpxs:
    try:
        routes = gpx.routes 
        for p in routes[0].points:
            points += [[p.latitude, p.longitude]]
        continue
    except:
        pass
    try:
        routes = gpx.tracks
        for p in routes[0].points:
            points += [[p.latitude, p.longitude]]
        continue
    except:
        pass
    
points = np.array(points)

# %%
np.save('gps_points', points)

# %%
from geojson import Point, Feature, FeatureCollection, dump, MultiPoint

# %%
d_points = np.concatenate([points, 0.2 * np.ones((points.shape[0],1))], axis=1)

# %%
features = []
features.append(MultiPoint(d_points[::1].tolist()))

# %%
# add more features...
# features.append(...)

feature_collection = FeatureCollection(features)

with open('gps_11.geojson', 'w') as f:
   dump(feature_collection, f)
